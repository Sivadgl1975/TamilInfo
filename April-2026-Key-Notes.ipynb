# %% [markdown]
# The 2025 AI Engineer Reading List  - https://www.latent.space/p/2025-papers?hide_intro_popup=true

# %% [markdown]
# LLM Agents Workflow - https://llmagents-learning.org/slides/agentworkflows.pdf

# %% [markdown]
# Agents Safety - https://rdi.berkeley.edu/llm-agents/assets/dawn-agent-safety.pdf

# %% [markdown]
# LLM University Course - https://rdi.berkeley.edu/llm-agents/f24
